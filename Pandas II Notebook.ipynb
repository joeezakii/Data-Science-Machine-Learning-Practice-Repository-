# %%
import pandas as pd

# %%
a_spreadsheet = pd.read_csv("heart.csv")

# %%
a_spreadsheet.head(23)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# 12   39   M           ATA        120          204          0     Normal
# 13   49   M           ASY        140          234          0     Normal
# 14   42   F           NAP        115          211          0         ST
# 15   54   F           ATA        120          273          0     Normal
# 16   38   M           ASY        110          196          0     Normal
# 17   43   F           ATA        120          201          0     Normal
# 18   60   M           ASY        100          248          0     Normal
# 19   36   M           ATA        120          267          0     Normal
# 20   43   F            TA        100          223          0     Normal
# 21   44   M           ATA        120          184          0     Normal
# 22   49   F           ATA        124          201          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     172              N      0.0       Up             0
# 1     156              N      1.0     Flat             1
# 2      98              N      0.0       Up             0
# 3     108              Y      1.5     Flat             1
# 4     122              N      0.0       Up             0
# 5     170              N      0.0       Up             0
# 6     170              N      0.0       Up             0
# 7     142              N      0.0       Up             0
# 8     130              Y      1.5     Flat             1
# 9     120              N      0.0       Up             0
# 10    142              N      0.0       Up             0
# 11     99              Y      2.0     Flat             1
# 12    145              N      0.0       Up             0
# 13    140              Y      1.0     Flat             1
# 14    137              N      0.0       Up             0
# 15    150              N      1.5     Flat             0
# 16    166              N      0.0     Flat             1
# 17    165              N      0.0       Up             0
# 18    125              N      1.0     Flat             1
# 19    160              N      3.0     Flat             1
# 20    142              N      0.0       Up             0
# 21    142              N      1.0     Flat             0
# 22    164              N      0.0       Up             0

# %%
a_spreadsheet.index = list(range(1,919))

# %%
a_spreadsheet.head(23)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1    40   M           ATA        140          289          0     Normal
# 2    49   F           NAP        160          180          0     Normal
# 3    37   M           ATA        130          283          0         ST
# 4    48   F           ASY        138          214          0     Normal
# 5    54   M           NAP        150          195          0     Normal
# 6    39   M           NAP        120          339          0     Normal
# 7    45   F           ATA        130          237          0     Normal
# 8    54   M           ATA        110          208          0     Normal
# 9    37   M           ASY        140          207          0     Normal
# 10   48   F           ATA        120          284          0     Normal
# 11   37   F           NAP        130          211          0     Normal
# 12   58   M           ATA        136          164          0         ST
# 13   39   M           ATA        120          204          0     Normal
# 14   49   M           ASY        140          234          0     Normal
# 15   42   F           NAP        115          211          0         ST
# 16   54   F           ATA        120          273          0     Normal
# 17   38   M           ASY        110          196          0     Normal
# 18   43   F           ATA        120          201          0     Normal
# 19   60   M           ASY        100          248          0     Normal
# 20   36   M           ATA        120          267          0     Normal
# 21   43   F            TA        100          223          0     Normal
# 22   44   M           ATA        120          184          0     Normal
# 23   49   F           ATA        124          201          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1     172              N      0.0       Up             0
# 2     156              N      1.0     Flat             1
# 3      98              N      0.0       Up             0
# 4     108              Y      1.5     Flat             1
# 5     122              N      0.0       Up             0
# 6     170              N      0.0       Up             0
# 7     170              N      0.0       Up             0
# 8     142              N      0.0       Up             0
# 9     130              Y      1.5     Flat             1
# 10    120              N      0.0       Up             0
# 11    142              N      0.0       Up             0
# 12     99              Y      2.0     Flat             1
# 13    145              N      0.0       Up             0
# 14    140              Y      1.0     Flat             1
# 15    137              N      0.0       Up             0
# 16    150              N      1.5     Flat             0
# 17    166              N      0.0     Flat             1
# 18    165              N      0.0       Up             0
# 19    125              N      1.0     Flat             1
# 20    160              N      3.0     Flat             1
# 21    142              N      0.0       Up             0
# 22    142              N      1.0     Flat             0
# 23    164              N      0.0       Up             0

# %%
a_spreadsheet.index.name = "Index"

# %%
a_spreadsheet.head(23)
# Out:
#        Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# Index
# 1       40   M           ATA        140          289          0     Normal
# 2       49   F           NAP        160          180          0     Normal
# 3       37   M           ATA        130          283          0         ST
# 4       48   F           ASY        138          214          0     Normal
# 5       54   M           NAP        150          195          0     Normal
# 6       39   M           NAP        120          339          0     Normal
# 7       45   F           ATA        130          237          0     Normal
# 8       54   M           ATA        110          208          0     Normal
# 9       37   M           ASY        140          207          0     Normal
# 10      48   F           ATA        120          284          0     Normal
# 11      37   F           NAP        130          211          0     Normal
# 12      58   M           ATA        136          164          0         ST
# 13      39   M           ATA        120          204          0     Normal
# 14      49   M           ASY        140          234          0     Normal
# 15      42   F           NAP        115          211          0         ST
# 16      54   F           ATA        120          273          0     Normal
# 17      38   M           ASY        110          196          0     Normal
# 18      43   F           ATA        120          201          0     Normal
# 19      60   M           ASY        100          248          0     Normal
# 20      36   M           ATA        120          267          0     Normal
# 21      43   F            TA        100          223          0     Normal
# 22      44   M           ATA        120          184          0     Normal
# 23      49   F           ATA        124          201          0     Normal
#
#        MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# Index
# 1        172              N      0.0       Up             0
# 2        156              N      1.0     Flat             1
# 3         98              N      0.0       Up             0
# 4        108              Y      1.5     Flat             1
# 5        122              N      0.0       Up             0
# 6        170              N      0.0       Up             0
# 7        170              N      0.0       Up             0
# 8        142              N      0.0       Up             0
# 9        130              Y      1.5     Flat             1
# 10       120              N      0.0       Up             0
# 11       142              N      0.0       Up             0
# 12        99              Y      2.0     Flat             1
# 13       145              N      0.0       Up             0
# 14       140              Y      1.0     Flat             1
# 15       137              N      0.0       Up             0
# 16       150              N      1.5     Flat             0
# 17       166              N      0.0     Flat             1
# 18       165              N      0.0       Up             0
# 19       125              N      1.0     Flat             1
# 20       160              N      3.0     Flat             1
# 21       142              N      0.0       Up             0
# 22       142              N      1.0     Flat             0
# 23       164              N      0.0       Up             0

# %%
sheet = a_spreadsheet.sample(frac=1)

# %%
sheet
# Out:
#        Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# Index
# 876     58   F           NAP        120          340          0     Normal
# 720     63   M           ASY        130          254          0        LVH
# 677     51   F           ASY        130          305          0     Normal
# 433     63   M           ASY        170          177          0     Normal
# 347     59   M           ASY        120            0          0     Normal
# ...    ...  ..           ...        ...          ...        ...        ...
# 140     43   M           ASY        150          247          0     Normal
# 485     65   M           ASY        134            0          0     Normal
# 107     48   F           ASY        120          254          0         ST
# 814     69   F            TA        140          239          0     Normal
# 482     69   M           NAP        140            0          1         ST
#
#        MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# Index
# 876      172              N      0.0       Up             0
# 720      147              N      1.4     Flat             1
# 677      142              Y      1.2     Flat             1
# 433       84              Y      2.5     Down             1
# 347      115              N      0.0     Flat             1
# ...      ...            ...      ...      ...           ...
# 140      130              Y      2.0     Flat             1
# 485      112              Y      1.1     Flat             1
# 107      110              N      0.0       Up             0
# 814      151              N      1.8       Up             0
# 482      118              N      2.5     Down             1
#
# [918 rows x 12 columns]

# %%
sheet.reset_index(drop=True, inplace=True)

# %%
sheet
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     58   F           NAP        120          340          0     Normal
# 1     63   M           ASY        130          254          0        LVH
# 2     51   F           ASY        130          305          0     Normal
# 3     63   M           ASY        170          177          0     Normal
# 4     59   M           ASY        120            0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   43   M           ASY        150          247          0     Normal
# 914   65   M           ASY        134            0          0     Normal
# 915   48   F           ASY        120          254          0         ST
# 916   69   F            TA        140          239          0     Normal
# 917   69   M           NAP        140            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      147              N      1.4     Flat             1
# 2      142              Y      1.2     Flat             1
# 3       84              Y      2.5     Down             1
# 4      115              N      0.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 913    130              Y      2.0     Flat             1
# 914    112              Y      1.1     Flat             1
# 915    110              N      0.0       Up             0
# 916    151              N      1.8       Up             0
# 917    118              N      2.5     Down             1
#
# [918 rows x 12 columns]

# %%
sheet.index = list(range(1,919))

# %%
sheet
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     58   F           NAP        120          340          0     Normal
# 2     63   M           ASY        130          254          0        LVH
# 3     51   F           ASY        130          305          0     Normal
# 4     63   M           ASY        170          177          0     Normal
# 5     59   M           ASY        120            0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 914   43   M           ASY        150          247          0     Normal
# 915   65   M           ASY        134            0          0     Normal
# 916   48   F           ASY        120          254          0         ST
# 917   69   F            TA        140          239          0     Normal
# 918   69   M           NAP        140            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1      172              N      0.0       Up             0
# 2      147              N      1.4     Flat             1
# 3      142              Y      1.2     Flat             1
# 4       84              Y      2.5     Down             1
# 5      115              N      0.0     Flat             1
# ..     ...            ...      ...      ...           ...
# 914    130              Y      2.0     Flat             1
# 915    112              Y      1.1     Flat             1
# 916    110              N      0.0       Up             0
# 917    151              N      1.8       Up             0
# 918    118              N      2.5     Down             1
#
# [918 rows x 12 columns]

# %%
sheet
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     58   F           NAP        120          340          0     Normal
# 2     63   M           ASY        130          254          0        LVH
# 3     51   F           ASY        130          305          0     Normal
# 4     63   M           ASY        170          177          0     Normal
# 5     59   M           ASY        120            0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 914   43   M           ASY        150          247          0     Normal
# 915   65   M           ASY        134            0          0     Normal
# 916   48   F           ASY        120          254          0         ST
# 917   69   F            TA        140          239          0     Normal
# 918   69   M           NAP        140            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease Cholestrol Rate
# 1      172              N      0.0       Up             0             NaN
# 2      147              N      1.4     Flat             1             NaN
# 3      142              Y      1.2     Flat             1             NaN
# 4       84              Y      2.5     Down             1             NaN
# 5      115              N      0.0     Flat             1             NaN
# ..     ...            ...      ...      ...           ...             ...
# 914    130              Y      2.0     Flat             1             NaN
# 915    112              Y      1.1     Flat             1             NaN
# 916    110              N      0.0       Up             0             NaN
# 917    151              N      1.8       Up             0             NaN
# 918    118              N      2.5     Down             1             NaN
#
# [918 rows x 13 columns]

# %%
sheet["Cholesterol Rate"] = sheet["Cholesterol"].apply(lambda x:x/1.6)

# %%
sheet
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     58   F           NAP        120          340          0     Normal
# 2     63   M           ASY        130          254          0        LVH
# 3     51   F           ASY        130          305          0     Normal
# 4     63   M           ASY        170          177          0     Normal
# 5     59   M           ASY        120            0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 914   43   M           ASY        150          247          0     Normal
# 915   65   M           ASY        134            0          0     Normal
# 916   48   F           ASY        120          254          0         ST
# 917   69   F            TA        140          239          0     Normal
# 918   69   M           NAP        140            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Cholestrol Rate  \
# 1      172              N      0.0       Up             0          212.500
# 2      147              N      1.4     Flat             1          158.750
# 3      142              Y      1.2     Flat             1          190.625
# 4       84              Y      2.5     Down             1          110.625
# 5      115              N      0.0     Flat             1            0.000
# ..     ...            ...      ...      ...           ...              ...
# 914    130              Y      2.0     Flat             1          154.375
# 915    112              Y      1.1     Flat             1            0.000
# 916    110              N      0.0       Up             0          158.750
# 917    151              N      1.8       Up             0          149.375
# 918    118              N      2.5     Down             1            0.000
#
#      Cholesterol Rate
# 1             212.500
# 2             158.750
# 3             190.625
# 4             110.625
# 5               0.000
# ..                ...
# 914           154.375
# 915             0.000
# 916           158.750
# 917           149.375
# 918             0.000
#
# [918 rows x 14 columns]
